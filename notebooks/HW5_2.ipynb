# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(1)
m=500
x1=5*np.random.rand(m,1)-3
y=10+(2*x1)+x1**2+2*x1**3+10*np.random.randn(m,1)

# %%
plt.figure(figsize=(3,2))
plt.plot(x1,y,'b.',markersize=1)
plt.xlabel('$x_1$',fontsize=18)
plt.ylabel('y',rotation=0,fontsize=18)
plt.show()

# %%
from sklearn.model_selection import train_test_split

x1_train,x1_test,y_train,y_test = train_test_split(x1,y,test_size=0.2,random_state=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor

# %%
pip_reg=Pipeline([
    ('poly',PolynomialFeatures(include_bias=False)),
    ('scal',StandardScaler()),
    ('sgd',SGDRegressor(penalty='elasticnet',random_state=1))
])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid=[{
    'poly__degree':[2,3,4],
    'sgd__alpha':[0.1,1,10],
    'sgd__l1_ratio':[0,0.5,1]
}]

# %%
grid_search=GridSearchCV(pip_reg,param_grid,scoring='r2',return_train_score=True,cv=3)

grid_search.fit(x1_train,y_train.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('poly',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('scal', StandardScaler()),
#                                        ('sgd',
#                                         SGDRegressor(penalty='elasticnet',
#                                                      random_state=1))]),
#              param_grid=[{'poly__degree': [2, 3, 4], 'sgd__alpha': [0.1, 1, 10],
#                           'sgd__l1_ratio': [0, 0.5, 1]}],
#              return_train_score=True, scoring='r2')

# %%
grid_search.best_score_
# Out:
# np.float64(0.7329379166794469)

# %%
grid_search.best_params_
# Out:
# {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}

# %%
grid_model=grid_search.best_estimator_

grid_model.score(x1_test,y_test)
# Out:
# 0.7287417714648952

# %%
grid_rlt=grid_search.cv_results_

for mean_score,params in zip(grid_rlt['mean_test_score'],grid_rlt['params']):
    print(np.sqrt(-mean_score),params)
# Out:
# nan {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# nan {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# nan {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# nan {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}
# <ipython-input-15-7faecdd132f4>:4: RuntimeWarning: invalid value encountered in sqrt
#   print(np.sqrt(-mean_score),params)

# %%
import pandas as pd

pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                13            0.677307            0.708229
# 1                12            0.679451            0.710540
# 2                11            0.680708            0.711576
# 3                18            0.567911            0.600991
# 4                17            0.628831            0.657883
# 5                14            0.677798            0.709030
# 6                27            0.160548            0.201993
# 7                26            0.183041            0.232322
# 8                21            0.377901            0.438099
# 9                 8            0.734500            0.764145
# 10                3            0.739765            0.770133
# 11                1            0.742423            0.776841
# 12               16            0.655834            0.687767
# 13               10            0.696293            0.721557
# 14                4            0.739599            0.769304
# 15               25            0.244802            0.299046
# 16               24            0.271815            0.334758
# 17               20            0.466105            0.526562
# 18                7            0.736864            0.764515
# 19                5            0.739739            0.768986
# 20                2            0.745638            0.773149
# 21               15            0.672039            0.691854
# 22                9            0.701925            0.725516
# 23                6            0.734340            0.766635
# 24               23            0.289478            0.312472
# 25               22            0.306988            0.381565
# 26               19            0.465599            0.526249
#
#     split2_train_score  mean_train_score  std_train_score
# 0             0.655283          0.680273         0.021717
# 1             0.657430          0.682474         0.021787
# 2             0.658440          0.683575         0.021787
# 3             0.548605          0.572502         0.021632
# 4             0.602874          0.629863         0.022469
# 5             0.654674          0.680501         0.022273
# 6             0.153779          0.172107         0.021313
# 7             0.171025          0.195463         0.026521
# 8             0.328350          0.381450         0.044875
# 9             0.705448          0.734697         0.023963
# 10            0.709599          0.739832         0.024713
# 11            0.713653          0.744306         0.025831
# 12            0.636709          0.660103         0.021062
# 13            0.668577          0.695476         0.021637
# 14            0.708109          0.739004         0.024986
# 15            0.236731          0.260193         0.027671
# 16            0.257762          0.288111         0.033479
# 17            0.411153          0.467940         0.047133
# 18            0.705293          0.735557         0.024195
# 19            0.707105          0.738610         0.025276
# 20            0.710343          0.743043         0.025706
# 21            0.646377          0.670090         0.018617
# 22            0.671637          0.699693         0.022052
# 23            0.706309          0.735761         0.024649
# 24            0.280487          0.294145         0.013469
# 25            0.291679          0.326744         0.039265
# 26            0.423318          0.471722         0.042244

# %%
plt.figure(figsize=(3,2))

x1s=np.linspace(x1.min(),x1.max(),100).reshape(-1,1)
y_pred=grid_model.predict(x1s)

plt.plot(x1,y,"b.",markersize=1)
plt.plot(x1s,y_pred,'r-',linewidth=2,label='$\hat y$')

plt.xlabel("$x_1$",fontsize=18)
plt.ylabel("y",rotation=0,fontsize=18)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_rnd=[{
    'poly__degree':range(1,11,1),
    'sgd__alpha':np.random.rand(100),
    'sgd__l1_ratio':np.random.rand(100)
}]

# %%
rnd_search=RandomizedSearchCV(pip_reg,param_rnd,scoring='r2',random_state=1,cv=3,n_iter=10)

rnd_search.fit(x1_train,y_train.ravel())
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('poly',
#                                               PolynomialFeatures(include_bias=False)),
#                                              ('scal', StandardScaler()),
#                                              ('sgd',
#                                               SGDRegressor(penalty='elasticnet',
#                                                            random_state=1))]),
#                    param_distributions=[{'poly__degree': range(1, 11),
#                                          'sgd__alpha': array([0.72130334, 0.44034709, 0.12673571, 0.58982365, 0.03606831,
#        0.20018212, 0.78830119, 0.01209676, 0.3033456...
#        1.84982966e-01, 8.44260005e-01, 9.82589789e-01, 9.13739625e-01,
#        3.47369420e-01, 7.80224580e-01, 5.46454591e-01, 8.16442398e-01,
#        4.83726951e-01, 5.89951298e-01, 7.87263448e-01, 1.00234643e-01,
#        5.37007117e-01, 3.65983347e-01, 6.04306844e-01, 9.58802516e-01,
#        3.92822945e-01, 3.92972998e-01, 7.90636994e-01, 6.45078399e-01,
#        3.93884008e-01, 6.88955048e-01, 4.04001609e-01, 1.36113154e-01])}],
#                    random_state=1, scoring='r2')

# %%
rnd_search.best_score_
# Out:
# np.float64(0.7296834716153899)

# %%
rnd_search.best_params_
# Out:
# {'sgd__l1_ratio': np.float64(0.9247408135383717),
#  'sgd__alpha': np.float64(0.151375569992799),
#  'poly__degree': 10}

# %%
rnd_model=rnd_search.best_estimator_

rnd_model.score(x1_test,y_test)
# Out:
# 0.7200654565989044

# %%
rnd_rlt=rnd_search.cv_results_

for mean_score,params in zip(rnd_rlt['mean_test_score'],rnd_rlt['params']):
    print(np.sqrt(-mean_score),params)
# Out:
# nan {'sgd__l1_ratio': np.float64(0.9247408135383717), 'sgd__alpha': np.float64(0.151375569992799), 'poly__degree': 10}
# nan {'sgd__l1_ratio': np.float64(0.3948822625368005), 'sgd__alpha': np.float64(0.6830743663365642), 'poly__degree': 8}
# nan {'sgd__l1_ratio': np.float64(0.39282294499696246), 'sgd__alpha': np.float64(0.3734071317371953), 'poly__degree': 1}
# nan {'sgd__l1_ratio': np.float64(0.19086994317230743), 'sgd__alpha': np.float64(0.8785878632047704), 'poly__degree': 10}
# nan {'sgd__l1_ratio': np.float64(0.8805385975643267), 'sgd__alpha': np.float64(0.7213033441865708), 'poly__degree': 6}
# nan {'sgd__l1_ratio': np.float64(0.8369977822135122), 'sgd__alpha': np.float64(0.7043133983839096), 'poly__degree': 8}
# nan {'sgd__l1_ratio': np.float64(0.38698923425629217), 'sgd__alpha': np.float64(0.5071194235482045), 'poly__degree': 3}
# nan {'sgd__l1_ratio': np.float64(0.11819262934703845), 'sgd__alpha': np.float64(0.34433919545005387), 'poly__degree': 10}
# nan {'sgd__l1_ratio': np.float64(0.46157971096238615), 'sgd__alpha': np.float64(0.7883011896679689), 'poly__degree': 3}
# nan {'sgd__l1_ratio': np.float64(0.07457407125147986), 'sgd__alpha': np.float64(0.5899231270757698), 'poly__degree': 5}
# <ipython-input-26-24a6a8313ce7>:4: RuntimeWarning: invalid value encountered in sqrt
#   print(np.sqrt(-mean_score),params)
